# %% [markdown]
# # Explanatory models of 10 Year Treasury Notes (1982-2021)

# %% [markdown]
# #### <font color='darkblue'>__1. Data and libaries import__</font> [(→ Link)](#data_import)
# #### <font color='darkblue'>__2. Exploratory Data Analysis (EDA)__</font> [(→ Link)](#eda)
# 2.1 Adding new columns<br>
# #### <font color='darkblue'>__3. Time Series Analysis__</font> [(→ Link)](#tsa)
# ##### <font color='black'>3.1 Testing for White Noise
# ##### <font color='black'>3.2 Testing for Stationary
# ##### <font color='black'>3.3 Decomposing the Time Series
# ##### <font color='black'>3.4 Create Train & Test set
# ##### <font color='black'>3.5 Moving-average
# 3.5.1 Moving-average forecast<br>
# ##### <font color='black'>3.6 Exponentially Weighted Moving Average
# 3.6.1 Exponentially Exponentially Weighted Moving Average forecast<br>
# ##### <font color='black'>3.7 Exponential Smoothing
# 3.7.1 Double Exponential Smoothing<br>
# 3.7.2 Triple Exponential Smoothing<br>
# #### <font color='darkblue'>__4. Feature Selection__</font> [(→ Link)](#fs)
# 4.1 Correlation analysis<br>
# 4.2 Filter Method<br>
# #### <font color='darkblue'>__5. Creating regression models with features from Filter Method__</font> [(→ Link)](#regression_fm)
# ##### <font color='black'>5.1 Linear Regression
# 5.1.1 Feature importance<br>
# ##### <font color='black'>5.2 Ridge
# 5.2.1 Rigde alpha 0.1<br>
# 5.2.2 Rigde alpha 1<br>
# 5.2.3 Rigde alpha 10<br>
# 5.2.4 Feature importance<br>
# ##### <font color='black'>5.3 LASSO Regression
# 5.3.1 Feature importance<br>
# ##### <font color='black'>5.4 ElasticNet
# 5.4.1 Feature importance<br>
# ##### <font color='black'>5.5 Decision Tree
# 5.5.1 Decision Tree max_depth 3<br>
# 5.5.2 Decision Tree max_depth 5<br>
# 5.5.3 Decision Tree max_depth 10<br>
# 5.5.4 Feature importance<br>
# ##### <font color='black'>5.6 Random Forest
# 5.6.1 Random Forest with 100 trees<br>
# 5.6.2 Random Forest with 500 trees<br>
# 5.6.3 Random Forest with 1000 trees<br>
# 5.6.4 Feature importance<br>
# ##### <font color='black'>5.7 XGBoost
# 5.7.1 XGBoost tree based<br>
# 5.7.2 XGBoost linear based<br>
# 5.7.3 Feature importance<br>
# ##### <font color='black'>5.8 Pipeline
# #### <font color='darkblue'>__6. Creating Regression models with all the features__</font> [(→ Link)](#regression_all)
# ##### <font color='black'>6.1 Linear Regression
# 6.1.1 Feature importance<br>
# ##### <font color='black'>6.2 Ridge
# 6.2.1 Rigde alpha 0.1<br>
# 6.2.2 Rigde alpha 1<br>
# 6.2.3 Rigde alpha 10<br>
# 6.2.4 Feature importance<br>
# ##### <font color='black'>6.3 LASSO Regression
# 6.3.1 Feature importance<br>
# ##### <font color='black'>6.4 ElasticNet
# 6.4.1 Feature importance<br>
# ##### <font color='black'>6.5 Decision Tree
# 6.5.1 Decision Tree max_depth 3<br>
# 6.5.2 Decision Tree max_depth 5<br>
# 6.5.3 Decision Tree max_depth 10<br>
# 6.5.4 Feature importance<br>
# ##### <font color='black'>6.6 Random Forest<br>
# 6.6.1 Random Forest with 100 trees<br>
# 6.6.2 Random Forest with 500 trees<br>
# 6.6.3 Random Forest with 1000 trees<br>
# 6.6.4 Feature importance<br>
# ##### <font color='black'>6.7 XGBoost
# 6.7.1 XGBoost tree based<br>
# 6.7.2 XGBoost linear based<br>
# 6.7.3 Feature importance<br>
# ##### <font color='black'>6.8 Pipeline
# <br>

# %% [markdown]
# ## <a id='data_import'></a>
# ## 1. Data and libaries import

# %%
# Loading libraries
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pmdarima as pm
import warnings  
import pydotplus
import pydot
import tensorflow as tf
import xgboost as xgb
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.stattools import kpss
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.tree import DecisionTreeRegressor # Decision Decision Tree Regressor
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn.metrics import *
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.neural_network import MLPClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNetCV
from matplotlib import rcParams
from matplotlib import pyplot
from cycler import cycler
from scipy.stats.stats import pearsonr
from six import StringIO 
from IPython.display import Image  
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from functools import reduce
from xgboost import XGBClassifier
warnings.filterwarnings('ignore')
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
# Import data and create dataframe
df_forecast = pd.read_excel('ALFRED_Data_1982-2021.xlsx', index_col=0)
df_forecast
# Out:
#             Yield of the ten-year Treasury Notes  Real Risk Premium  \
# Date
# 1982-01-01                                 14.59           1.236861
# 1982-02-01                                 14.43           1.231781
# 1982-03-01                                 13.86           1.165725
# 1982-04-01                                 13.87           1.257839
# 1982-05-01                                 13.62           1.157556
# ...                                          ...                ...
# 2021-06-01                                  1.52           1.146639
# 2021-07-01                                  1.32           1.156082
# 2021-08-01                                  1.28           1.106154
# 2021-09-01                                  1.37           1.151900
# 2021-10-01                                  1.58           1.164060
#
#             Inflation Risk Premium  National Activity Index  \
# Date
# 1982-01-01                0.423299                    -1.75
# 1982-02-01                0.346621                     0.87
# 1982-03-01                0.329844                    -0.94
# 1982-04-01                0.404000                    -1.05
# 1982-05-01                0.328358                    -0.60
# ...                            ...                      ...
# 2021-06-01                0.334032                     0.21
# 2021-07-01                0.353131                     0.71
# 2021-08-01                0.386107                     0.03
# 2021-09-01                0.391759                    -0.07
# 2021-10-01                0.388468                     0.82
#
#             Consumer Sentiment  Labor Force Participation  Unemploymentrate  \
# Date
# 1982-01-01                71.0                       63.7               8.6
# 1982-02-01                66.5                       63.8               8.9
# 1982-03-01                62.0                       63.8               9.0
# 1982-04-01                65.5                       63.9               9.3
# 1982-05-01                67.5                       64.2               9.4
# ...                        ...                        ...               ...
# 2021-06-01                85.5                       61.6               5.9
# 2021-07-01                81.2                       61.7               5.4
# 2021-08-01                70.3                       61.7               5.2
# 2021-09-01                72.8                       61.7               4.7
# 2021-10-01                71.7                       61.7               4.6
#
#             Borrowings from FED  Reserves Depository Institutions       M2  \
# Date
# 1982-01-01               1.5175                              43.2   1770.4
# 1982-02-01               1.7895                              41.3   1774.5
# 1982-03-01               1.5548                              39.2   1786.5
# 1982-04-01               1.5678                              39.6   1803.9
# 1982-05-01               1.1174                              39.5   1815.4
# ...                         ...                               ...      ...
# 2021-06-01              87.7460                            3848.1  20458.9
# 2021-07-01              87.6211                            3943.9  20620.0
# 2021-08-01              80.7667                            4140.1  20852.3
# 2021-09-01              68.5677                            4193.2  20991.3
# 2021-10-01              54.5588                            4128.1  21142.0
#
#             ...  1-Year Expected Inflation  2-Year Expected Inflation  \
# Date        ...
# 1982-01-01  ...                   6.394507                   6.452048
# 1982-02-01  ...                   6.432108                   6.472865
# 1982-03-01  ...                   6.387732                   6.295533
# 1982-04-01  ...                   6.140628                   6.222733
# 1982-05-01  ...                   5.488167                   5.852202
# ...         ...                        ...                        ...
# 2021-06-01  ...                   2.055189                   1.704123
# 2021-07-01  ...                   2.073116                   1.724717
# 2021-08-01  ...                   2.462413                   1.873715
# 2021-09-01  ...                   2.684137                   2.007175
# 2021-10-01  ...                   1.854368                   1.614725
#
#             3-Year Expected Inflation  4-Year Expected Inflation  \
# Date
# 1982-01-01                   6.496818                   6.503120
# 1982-02-01                   6.476419                   6.450152
# 1982-03-01                   6.202595                   6.113259
# 1982-04-01                   6.191583                   6.132849
# 1982-05-01                   5.948390                   5.963829
# ...                               ...                        ...
# 2021-06-01                   1.586923                   1.540665
# 2021-07-01                   1.610817                   1.566884
# 2021-08-01                   1.674370                   1.588064
# 2021-09-01                   1.779203                   1.679105
# 2021-10-01                   1.540890                   1.517656
#
#             5-Year Expected Inflation  10-Year Expected Inflation  \
# Date
# 1982-01-01                   6.480940                    6.197611
# 1982-02-01                   6.404901                    6.079232
# 1982-03-01                   6.027709                    5.648130
# 1982-04-01                   6.064913                    5.713188
# 1982-05-01                   5.943919                    5.689980
# ...                               ...                         ...
# 2021-06-01                   1.525682                    1.596289
# 2021-07-01                   1.553350                    1.624811
# 2021-08-01                   1.549929                    1.580163
# 2021-09-01                   1.632602                    1.642786
# 2021-10-01                   1.516703                    1.612740
#
#             Velocity of M2        GDP      Real GDP  Federal Debt
# Date
# 1982-01-01        1.842000  -0.800000   6799.233000  1.061299e+06
# 1982-02-01        1.840000   1.866667   6809.572333  1.067409e+06
# 1982-03-01        1.838000   4.533333   6819.911667  1.073520e+06
# 1982-04-01        1.836000   7.200000   6830.251000  1.079630e+06
# 1982-05-01        1.832333   6.200000   6821.547000  1.100432e+06
# ...                    ...        ...           ...           ...
# 2021-06-01        1.115667  10.066667  19442.032000  2.846242e+07
# 2021-07-01        1.114000   8.400000  19478.893000  2.842892e+07
# 2021-08-01        1.118000  10.433333  19588.025333  2.882502e+07
# 2021-09-01        1.122000  12.466667  19697.157667  2.922112e+07
# 2021-10-01        1.126000  14.500000  19806.290000  2.961722e+07
#
# [478 rows x 24 columns]

# %% [markdown]
# ## <a id='eda'></a>
# ## 2. Exploratory Data Analysis (EDA)

# %%
# Return the numbers of rows for each column
df_forecast.count()
# Out:
# Yield of the ten-year Treasury Notes    478
# Real Risk Premium                       478
# Inflation Risk Premium                  478
# National Activity Index                 478
# Consumer Sentiment                      478
# Labor Force Participation               478
# Unemploymentrate                        478
# Borrowings from FED                     478
# Reserves Depository Institutions        478
# M2                                      478
# M3                                      478
# 1-Month Real Interest                   478
# 1-Year Real Interest                    478
# 10-Year Real Interest                   478
# 1-Year Expected Inflation               478
# 2-Year Expected Inflation               478
# 3-Year Expected Inflation               478
# 4-Year Expected Inflation               478
# 5-Year Expected Inflation               478
# 10-Year Expected Inflation              478
# Velocity of M2                          478
# GDP                                     478
# Real GDP                                478
# Federal Debt                            478
# dtype: int64

# %%
# Return a tuple representing the dimensionality of the dataframe
df_forecast.shape
# Out:
# (478, 24)

# %%
# Print a concise summary of the dataframe
df_forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 478 entries, 1982-01-01 to 2021-10-01
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Yield of the ten-year Treasury Notes  478 non-null    float64
#  1   Real Risk Premium                     478 non-null    float64
#  2   Inflation Risk Premium                478 non-null    float64
#  3   National Activity Index               478 non-null    float64
#  4   Consumer Sentiment                    478 non-null    float64
#  5   Labor Force Participation             478 non-null    float64
#  6   Unemploymentrate                      478 non-null    float64
#  7   Borrowings from FED                   478 non-null    float64
#  8   Reserves Depository Institutions      478 non-null    float64
#  9   M2                                    478 non-null    float64
#  10  M3                                    478 non-null    float64
#  11  1-Month Real Interest                 478 non-null    float64
#  12  1-Year Real Interest                  478 non-null    float64
#  13  10-Year Real Interest                 478 non-null    float64
#  14  1-Year Expected Inflation             478 non-null    float64
#  15  2-Year Expected Inflation             478 non-null    float64
#  16  3-Year Expected Inflation             478 non-null    float64
#  17  4-Year Expected Inflation             478 non-null    float64
#  18  5-Year Expected Inflation             478 non-null    float64
#  19  10-Year Expected Inflation            478 non-null    float64
#  20  Velocity of M2                        478 non-null    float64
#  21  GDP                                   478 non-null    float64
#  22  Real GDP                              478 non-null    float64
#  23  Federal Debt                          478 non-null    float64
# dtypes: float64(24)
# memory usage: 93.4 KB

# %%
# Search the dataframe if there are NA or None values
df_forecast.isna().sum()
df_forecast.isnull().sum()
# Out:
# Yield of the ten-year Treasury Notes    0
# Real Risk Premium                       0
# Inflation Risk Premium                  0
# National Activity Index                 0
# Consumer Sentiment                      0
# Labor Force Participation               0
# Unemploymentrate                        0
# Borrowings from FED                     0
# Reserves Depository Institutions        0
# M2                                      0
# M3                                      0
# 1-Month Real Interest                   0
# 1-Year Real Interest                    0
# 10-Year Real Interest                   0
# 1-Year Expected Inflation               0
# 2-Year Expected Inflation               0
# 3-Year Expected Inflation               0
# 4-Year Expected Inflation               0
# 5-Year Expected Inflation               0
# 10-Year Expected Inflation              0
# Velocity of M2                          0
# GDP                                     0
# Real GDP                                0
# Federal Debt                            0
# dtype: int64

# %%
# Return how many unique values there are
df_forecast.nunique()
# Out:
# Yield of the ten-year Treasury Notes    372
# Real Risk Premium                       478
# Inflation Risk Premium                  478
# National Activity Index                 189
# Consumer Sentiment                      277
# Labor Force Participation                56
# Unemploymentrate                         73
# Borrowings from FED                     466
# Reserves Depository Institutions        343
# M2                                      478
# M3                                      478
# 1-Month Real Interest                   478
# 1-Year Real Interest                    478
# 10-Year Real Interest                   478
# 1-Year Expected Inflation               478
# 2-Year Expected Inflation               478
# 3-Year Expected Inflation               478
# 4-Year Expected Inflation               478
# 5-Year Expected Inflation               478
# 10-Year Expected Inflation              478
# Velocity of M2                          415
# GDP                                     255
# Real GDP                                478
# Federal Debt                            478
# dtype: int64

# %%
# Generate descriptive statistics
pd.options.display.float_format = '{:.2f}'.format
df_forecast.describe()
# Out:
#        Yield of the ten-year Treasury Notes  Real Risk Premium  \
# count                                478.00             478.00
# mean                                   5.47               1.24
# std                                    3.08               0.08
# min                                    0.62               1.02
# 25%                                    2.86               1.18
# 50%                                    5.00               1.23
# 75%                                    7.38               1.28
# max                                   14.59               1.53
#
#        Inflation Risk Premium  National Activity Index  Consumer Sentiment  \
# count                  478.00                   478.00              478.00
# mean                     0.41                    -0.04               87.67
# std                      0.07                     1.07               11.76
# min                     -0.12                   -17.89               55.30
# 25%                      0.38                    -0.28               79.93
# 50%                      0.42                     0.03               90.75
# 75%                      0.45                     0.30               95.57
# max                      0.59                     5.97              112.00
#
#        Labor Force Participation  Unemploymentrate  Borrowings from FED  \
# count                     478.00            478.00               478.00
# mean                       65.16              6.17                23.24
# std                         1.63              1.78                89.30
# min                        60.20              3.50                 0.00
# 25%                        63.80              4.90                 0.13
# 50%                        65.90              5.70                 0.32
# 75%                        66.50              7.20                 1.33
# max                        67.30             14.70               698.79
#
#        Reserves Depository Institutions       M2  ...  \
# count                            478.00   478.00  ...
# mean                             709.34  6867.39  ...
# std                             1046.43  4539.67  ...
# min                               36.20  1770.40  ...
# 25%                               44.25  3374.45  ...
# 50%                               56.55  5407.30  ...
# 75%                             1557.72  9599.98  ...
# max                             4193.20 21142.00  ...
#
#        1-Year Expected Inflation  2-Year Expected Inflation  \
# count                     478.00                     478.00
# mean                        2.78                       2.81
# std                         1.21                       1.23
# min                        -0.48                       0.42
# 25%                         1.85                       1.77
# 50%                         2.68                       2.64
# 75%                         3.48                       3.54
# max                         6.43                       6.47
#
#        3-Year Expected Inflation  4-Year Expected Inflation  \
# count                     478.00                     478.00
# mean                        2.82                       2.83
# std                         1.23                       1.23
# min                         0.65                       0.78
# 25%                         1.79                       1.80
# 50%                         2.63                       2.63
# 75%                         3.58                       3.60
# max                         6.50                       6.50
#
#        5-Year Expected Inflation  10-Year Expected Inflation  Velocity of M2  \
# count                     478.00                      478.00          478.00
# mean                        2.84                        2.86            1.81
# std                         1.21                        1.10            0.26
# min                         0.86                        1.16            1.10
# 25%                         1.81                        1.92            1.65
# 50%                         2.62                        2.64            1.83
# 75%                         3.60                        3.59            1.99
# max                         6.48                        6.20            2.19
#
#          GDP  Real GDP  Federal Debt
# count 478.00    478.00        478.00
# mean    5.22  13142.20    9390520.10
# std     4.22   3721.71    7396826.08
# min   -32.40   6799.23    1061299.00
# 25%     3.80   9512.23    3861390.50
# 50%     5.17  13339.90    5974735.50
# 75%     6.88  16081.52   15318834.50
# max    38.70  19806.29   29617215.00
#
# [8 rows x 24 columns]

# %%
forecast = df_forecast['Yield of the ten-year Treasury Notes']

# %%
# Display the changes of the "Yield of the ten-year Treasury Notes" dataset over time
rcParams['figure.figsize'] = 18, 5
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False
rcParams['axes.prop_cycle'] = cycler(color=['#365977'])
rcParams['lines.linewidth'] = 2.5
# Plot
plt.title('Yield of the ten-year Treasury Notes', size=20)
plt.xlabel('Time Period', size=14)
plt.ylabel('Yield', size=14)
plt.plot(forecast);
# plt.savefig('Change of the yield of the ten-year Treasury Notes.pdf', dpi= 1000)

# %%
# Display the distribution of the "Yield on U.S. Treasury Notes" dataset in a boxplot
sns.boxplot(x = df_forecast['Yield of the ten-year Treasury Notes'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Display the distribution of the "Yield on U.S. Treasury Notes" dataset in a histogram
sns.distplot(df_forecast['Yield of the ten-year Treasury Notes'], bins = 15, kde = False)
# plt.savefig('Histrogram of the yield of the ten-year Treasury Notes.pdf', dpi= 1000)
plt.show()

# %%
# Display the distribution of the "Yield on U.S. Treasury Notes" dataset in a boxplot with labels
# Set style
sns.set(style='white')

# Set figure size
fig, ax = plt.subplots(figsize=(10,2))

# Create box plot
sns.boxplot(df_forecast['Yield of the ten-year Treasury Notes'], color='plum', width=.5)

# Title and x-label
plt.title('Yield of the ten-year Treasury Notes', fontsize=14)
plt.xlabel('Levels')

# Despine
sns.despine()

# Add full range of value to the x-axis
plt.xlim([0,6])
plt.xticks(np.arange(0,18,2))
# plt.savefig('Boxplot of the yield of the ten-year Treasury Notes.pdf', dpi= 1000)
plt.show()

# %%
# Display the density distribution
df_forecast[['Yield of the ten-year Treasury Notes']].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Display a scatter plot with lag 1
pd.plotting.lag_plot(df_forecast['Yield of the ten-year Treasury Notes'],lag=1)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# Display a scatter plot with lag 12, for a year
pd.plotting.lag_plot(df_forecast['Yield of the ten-year Treasury Notes'],lag=12)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 12)'>

# %%
# Display a scatter plot with lag 6, for a half year
pd.plotting.lag_plot(df_forecast['Yield of the ten-year Treasury Notes'],lag=6)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 6)'>

# %%
# Display all datasets in a plot
df_forecast.plot(subplots=True, figsize=(30,20))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %% [markdown]
# ### 2.1 Adding new columns

# %%
# Calcualte different mean
quarterly_mean = df_forecast.rolling(4).mean()
half_year_mean = df_forecast.rolling(6).mean()
annual_mean = df_forecast.rolling(12).mean()

# %%
# Create new columns
df_forecast["quarterly_mean"] = quarterly_mean["Yield of the ten-year Treasury Notes"] / df_forecast["Yield of the ten-year Treasury Notes"]
df_forecast["half_year_mean"] = half_year_mean["Yield of the ten-year Treasury Notes"] / df_forecast["Yield of the ten-year Treasury Notes"]
df_forecast["annual_mean"] = annual_mean["Yield of the ten-year Treasury Notes"] / df_forecast["Yield of the ten-year Treasury Notes"]

# %%
# Create new columns
df_forecast["annual_quarterly_mean"] = df_forecast["annual_mean"] / df_forecast["quarterly_mean"]
df_forecast["annual_half_mean"] = df_forecast["annual_mean"] / df_forecast["half_year_mean"]

# %%
# Dropping the first 11 rows because of NAN values
df_forecast = df_forecast.iloc[11: , :]

# %%
df_forecast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 467 entries, 1982-12-01 to 2021-10-01
# Data columns (total 29 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Yield of the ten-year Treasury Notes  467 non-null    float64
#  1   Real Risk Premium                     467 non-null    float64
#  2   Inflation Risk Premium                467 non-null    float64
#  3   National Activity Index               467 non-null    float64
#  4   Consumer Sentiment                    467 non-null    float64
#  5   Labor Force Participation             467 non-null    float64
#  6   Unemploymentrate                      467 non-null    float64
#  7   Borrowings from FED                   467 non-null    float64
#  8   Reserves Depository Institutions      467 non-null    float64
#  9   M2                                    467 non-null    float64
#  10  M3                                    467 non-null    float64
#  11  1-Month Real Interest                 467 non-null    float64
#  12  1-Year Real Interest                  467 non-null    float64
#  13  10-Year Real Interest                 467 non-null    float64
#  14  1-Year Expected Inflation             467 non-null    float64
#  15  2-Year Expected Inflation             467 non-null    float64
#  16  3-Year Expected Inflation             467 non-null    float64
#  17  4-Year Expected Inflation             467 non-null    float64
#  18  5-Year Expected Inflation             467 non-null    float64
#  19  10-Year Expected Inflation            467 non-null    float64
#  20  Velocity of M2                        467 non-null    float64
#  21  GDP                                   467 non-null    float64
#  22  Real GDP                              467 non-null    float64
#  23  Federal Debt                          467 non-null    float64
#  24  quarterly_mean                        467 non-null    float64
#  25  half_year_mean                        467 non-null    float64
#  26  annual_mean                           467 non-null    float64
#  27  annual_quarterly_mean                 467 non-null    float64
#  28  annual_half_mean                      467 non-null    float64
# dtypes: float64(29)
# memory usage: 109.5 KB

# %% [markdown]
# ## <a id='tsa'></a>
# ## 3. Time series analysis

# %% [markdown]
# ### 3.1 Testing for White Noise

# %%
# Split into an arbitraty number of chunks
white_noise_chunks = np.split(forecast, 239)
means, stds = [], []

# Get the mean and std values for every chunk
for chunk in white_noise_chunks:
    means.append(np.mean(chunk))
    stds.append(np.std(chunk))
      
# Plot
plt.title('White Noise Mean and Standard Deviation Comparison', size=20)
plt.plot(np.arange(len(means)), [forecast.mean()] * len(means), label='Global mean', lw=1.5)
plt.scatter(x=np.arange(len(means)), y=means, label='Mean', s=100)
plt.plot(np.arange(len(stds)), [forecast.std()] * len(stds), label='Global std', lw=1.5, color='orange')
plt.scatter(x=np.arange(len(stds)), y=stds, label='STD', color='orange', s=100)
plt.legend();
# plt.savefig('White Noise of the yield of the ten-year Treasury Notes.pdf', dpi= 1000)

# %%
# Display the Autocorrelation
plot_acf(np.array(forecast));
# plt.savefig('Autocorrelation of the yield of the ten-year Treasury Notes.pdf', dpi= 1000)

# %% [markdown]
# ### 3.2 Testing for Stationary

# %%
# Create new dataframe
white_noise = df_forecast.copy()

# %%
# Display the changes of the "Yield of the ten-year Treasury Notes" dataset over time
plt.title('Yield of the ten-year Treasury Notes', size=20)
plt.xlabel('Time Period', size=14)
plt.ylabel('Yield', size=14)
plt.plot(forecast);

# %%
# Make Stationary test with adfuller function
result = adfuller(white_noise['Yield of the ten-year Treasury Notes'])

# %%
# Print results
print(f'Test Statistics: {result[0]}')
print(f'p-value: {result[1]}')
print(f'Critial Values: {result[4]}')

if result[1] > 0.05 :
  print('Series is not Stationary')
else:
  print('Series is Stationary')
# Out:
# Test Statistics: -1.4831266588998513
# p-value: 0.5418412156462022
# Critial Values: {'1%': -3.4446148284445153, '5%': -2.8678299626609314, '10%': -2.5701203107928157}
# Series is not Stationary

# %% [markdown]
# ### 3.3 Decomposing the Time Series

# %%
# Decompose and plot with additive method
decomposed = seasonal_decompose(forecast, model='additive')
decomposed.plot();
# plt.savefig('Decompose additive method.pdf', dpi= 1000)

# %%
# Decompose and plot with multiplicative
decomposed = seasonal_decompose(forecast, model='multiplicative')
decomposed.plot();
# plt.savefig('Decompose multiplicative method.pdf', dpi= 1000)

# %% [markdown]
# ### 3.4 Create Train & Test set

# %%
# Train data from 1982-12 until 2014-01
df_train = df_forecast['1982-12-01':'2014-01-01']

df_train.count()
# Out:
# Yield of the ten-year Treasury Notes    374
# Real Risk Premium                       374
# Inflation Risk Premium                  374
# National Activity Index                 374
# Consumer Sentiment                      374
# Labor Force Participation               374
# Unemploymentrate                        374
# Borrowings from FED                     374
# Reserves Depository Institutions        374
# M2                                      374
# M3                                      374
# 1-Month Real Interest                   374
# 1-Year Real Interest                    374
# 10-Year Real Interest                   374
# 1-Year Expected Inflation               374
# 2-Year Expected Inflation               374
# 3-Year Expected Inflation               374
# 4-Year Expected Inflation               374
# 5-Year Expected Inflation               374
# 10-Year Expected Inflation              374
# Velocity of M2                          374
# GDP                                     374
# Real GDP                                374
# Federal Debt                            374
# quarterly_mean                          374
# half_year_mean                          374
# annual_mean                             374
# annual_quarterly_mean                   374
# annual_half_mean                        374
# dtype: int64

# %%
# Test data from 2014-02 until 2021-10
df_test = df_forecast['2014-02-01':'2021-10-01']

df_test.count()
# Out:
# Yield of the ten-year Treasury Notes    93
# Real Risk Premium                       93
# Inflation Risk Premium                  93
# National Activity Index                 93
# Consumer Sentiment                      93
# Labor Force Participation               93
# Unemploymentrate                        93
# Borrowings from FED                     93
# Reserves Depository Institutions        93
# M2                                      93
# M3                                      93
# 1-Month Real Interest                   93
# 1-Year Real Interest                    93
# 10-Year Real Interest                   93
# 1-Year Expected Inflation               93
# 2-Year Expected Inflation               93
# 3-Year Expected Inflation               93
# 4-Year Expected Inflation               93
# 5-Year Expected Inflation               93
# 10-Year Expected Inflation              93
# Velocity of M2                          93
# GDP                                     93
# Real GDP                                93
# Federal Debt                            93
# quarterly_mean                          93
# half_year_mean                          93
# annual_mean                             93
# annual_quarterly_mean                   93
# annual_half_mean                        93
# dtype: int64

# %% [markdown]
# ### 3.5 Moving-average

# %%
# Create new dataframe
moving_averages = df_forecast.copy()

# %%
# Calculcate Moving-averages
moving_averages['MA3'] = moving_averages['Yield of the ten-year Treasury Notes'].rolling(window=3).mean()
moving_averages['MA6'] = moving_averages['Yield of the ten-year Treasury Notes'].rolling(window=6).mean()
moving_averages['MA12'] = moving_averages['Yield of the ten-year Treasury Notes'].rolling(window=12).mean()

# Plot
plt.title('Yield of the ten-year Treasury Notes - Moving-average', size=20)
plt.plot(moving_averages['Yield of the ten-year Treasury Notes'], label='Original')
plt.plot(moving_averages['MA3'], color='green', label='MA3')
plt.plot(moving_averages['MA6'], color='orange', label='MA6')
plt.plot(moving_averages['MA12'], color='red', label='MA12')
plt.legend();
# plt.savefig('Moving-average.pdf', dpi= 1000)

# %% [markdown]
# #### 3.5.1 Moving-average forecast

# %%
# Train the model
model = ARMA(df_train['Yield of the ten-year Treasury Notes'], order=(0, 1))
results = model.fit()
predictions = results.forecast(steps=93)

predictions_df = pd.DataFrame(index=df_test.index, data=predictions[0])

# Plot
plt.title('Yield of the ten-year Treasury Notes - Moving-average predictions', size=20)
plt.plot(df_train['Yield of the ten-year Treasury Notes'], label='Training data')
plt.plot(df_test['Yield of the ten-year Treasury Notes'], color='orange', label='Testing data')
plt.plot(predictions_df, color='red', label='Predictions')
plt.legend();
# plt.savefig('Moving-average forecast.pdf', dpi= 1000)

# %% [markdown]
# ### 3.6 Exponentially Weighted Moving Average

# %%
# Calculate Exponentially Weighted Moving Average
moving_averages['EWMA3'] = moving_averages['Yield of the ten-year Treasury Notes'].ewm(span=3, adjust=False).mean()
moving_averages['EWMA6'] = moving_averages['Yield of the ten-year Treasury Notes'].ewm(span=6, adjust=False).mean()
moving_averages['EWMA12'] = moving_averages['Yield of the ten-year Treasury Notes'].ewm(span=12, adjust=False).mean()

# Plot
plt.title('Yield of the ten-year Treasury Notes - Exponentially Weighted Moving Average', size=20)
plt.plot(moving_averages['Yield of the ten-year Treasury Notes'], label='Original')
plt.plot(moving_averages['EWMA3'], color='green', label='EWMA3')
plt.plot(moving_averages['EWMA6'], color='orange', label='EWMA6')
plt.plot(moving_averages['EWMA12'], color='red', label='EWMA12')
plt.legend();
# plt.savefig('Exponentially Weighted Moving Average.pdf', dpi= 1000)

# %% [markdown]
# #### 3.6.1 Exponentially Exponentially Weighted Moving Average forecast

# %%
# Create forecasting model Exponentially Weighted Moving Average
# Model parameters
span = 12 
alpha = 2 / (span + 1)

# Train the model
model = SimpleExpSmoothing(df_train['Yield of the ten-year Treasury Notes'])
results = model.fit(smoothing_level=alpha, optimized=False)
predictions = results.forecast(steps=93)

# Plot
plt.title('Yield of the ten-year Treasury Notes - Exponentially Weighted Moving Average predictions', size=20)
plt.plot(df_train['Yield of the ten-year Treasury Notes'], label='Training data')
plt.plot(df_test['Yield of the ten-year Treasury Notes'], color='orange', label='Testing data')
plt.plot(predictions, color='red', label='Predictions')
plt.legend();
# plt.savefig('Exponentially Weighted Moving Average forecast.pdf', dpi= 1000)

# %% [markdown]
# ### 3.7 Exponential Smoothing

# %%
# Change index to monthly
df_forecast.index.freq = 'MS'

# %% [markdown]
# #### 3.7.1 Double Exponential Smoothing

# %%
# Create multiplicative model
model_mul = ExponentialSmoothing(df_train['Yield of the ten-year Treasury Notes'], trend='mul')
results_mul = model_mul.fit()
predictions_mul = results_mul.forecast(steps=93)

# Plot
plt.title('Yield of the ten-year Treasury Notes - Double Exponential Smoothing predictions', size=20)
plt.plot(df_train['Yield of the ten-year Treasury Notes'], label='Training data')
plt.plot(df_test['Yield of the ten-year Treasury Notes'], color='orange', label='Testing data')
plt.plot(predictions_mul, color='red', label='Predictions Multiplicative')
plt.legend();
# plt.savefig('Double Exponential Smoothing.pdf', dpi= 1000)

# %% [markdown]
# #### 3.7.2 Triple Exponential Smoothing

# %%
# Multiplicative trend / Multiplicative seasonality model
model_mul_mul = ExponentialSmoothing(df_train['Yield of the ten-year Treasury Notes'], trend='mul', seasonal='mul', initialization_method='estimated')
results_mul_mul = model_mul_mul.fit()
predictions_mul_mul = results_mul_mul.forecast(steps=93)

# Plot
plt.title('Yield of the ten-year Treasury Notes - Triple Exponential Smoothing predictions', size=20)
plt.plot(df_train['Yield of the ten-year Treasury Notes'], label='Training data')
plt.plot(df_test['Yield of the ten-year Treasury Notes'], color='orange', label='Testing data')
plt.plot(predictions_mul_mul, color='red', label='Predictions Multiplicative trend, Multiplicative seasonality')
plt.legend();
# plt.savefig('Triple Exponential Smoothing.pdf', dpi= 1000)

# %% [markdown]
# ## <a id='fs'></a>
# ## 4. Feature Selection

# %% [markdown]
# ### 4.1 Correlation analysis

# %%
# Return the correlation between the datasets
corr = df_forecast.corr()
corr
# Out:
#                                       Yield of the ten-year Treasury Notes  \
# Yield of the ten-year Treasury Notes                                  1.00
# Real Risk Premium                                                     0.50
# Inflation Risk Premium                                                0.31
# National Activity Index                                               0.13
# Consumer Sentiment                                                    0.27
# Labor Force Participation                                             0.49
# Unemploymentrate                                                      0.12
# Borrowings from FED                                                  -0.20
# Reserves Depository Institutions                                     -0.71
# M2                                                                   -0.84
# M3                                                                   -0.14
# 1-Month Real Interest                                                 0.69
# 1-Year Real Interest                                                  0.84
# 10-Year Real Interest                                                 0.99
# 1-Year Expected Inflation                                             0.94
# 2-Year Expected Inflation                                             0.98
# 3-Year Expected Inflation                                             0.99
# 4-Year Expected Inflation                                             0.99
# 5-Year Expected Inflation                                             0.99
# 10-Year Expected Inflation                                            0.99
# Velocity of M2                                                        0.49
# GDP                                                                   0.29
# Real GDP                                                             -0.94
# Federal Debt                                                         -0.85
# quarterly_mean                                                       -0.12
# half_year_mean                                                       -0.15
# annual_mean                                                          -0.21
# annual_quarterly_mean                                                -0.19
# annual_half_mean                                                     -0.18
#
#                                       Real Risk Premium  \
# Yield of the ten-year Treasury Notes               0.50
# Real Risk Premium                                  1.00
# Inflation Risk Premium                             0.80
# National Activity Index                            0.20
# Consumer Sentiment                                 0.34
# Labor Force Participation                          0.28
# Unemploymentrate                                  -0.06
# Borrowings from FED                               -0.17
# Reserves Depository Institutions                  -0.33
# M2                                                -0.41
# M3                                                -0.34
# 1-Month Real Interest                              0.19
# 1-Year Real Interest                               0.27
# 10-Year Real Interest                              0.51
# 1-Year Expected Inflation                          0.45
# 2-Year Expected Inflation                          0.48
# 3-Year Expected Inflation                          0.49
# 4-Year Expected Inflation                          0.49
# 5-Year Expected Inflation                          0.50
# 10-Year Expected Inflation                         0.50
# Velocity of M2                                     0.32
# GDP                                                0.23
# Real GDP                                          -0.40
# Federal Debt                                      -0.41
# quarterly_mean                                    -0.42
# half_year_mean                                    -0.50
# annual_mean                                       -0.55
# annual_quarterly_mean                             -0.48
# annual_half_mean                                  -0.40
#
#                                       Inflation Risk Premium  \
# Yield of the ten-year Treasury Notes                    0.31
# Real Risk Premium                                       0.80
# Inflation Risk Premium                                  1.00
# National Activity Index                                 0.27
# Consumer Sentiment                                      0.26
# Labor Force Participation                               0.25
# Unemploymentrate                                       -0.07
# Borrowings from FED                                    -0.25
# Reserves Depository Institutions                       -0.22
# M2                                                     -0.32
# M3                                                     -0.42
# 1-Month Real Interest                                  -0.04
# 1-Year Real Interest                                   -0.03
# 10-Year Real Interest                                   0.31
# 1-Year Expected Inflation                               0.31
# 2-Year Expected Inflation                               0.30
# 3-Year Expected Inflation                               0.30
# 4-Year Expected Inflation                               0.31
# 5-Year Expected Inflation                               0.31
# 10-Year Expected Inflation                              0.31
# Velocity of M2                                          0.30
# GDP                                                     0.26
# Real GDP                                               -0.27
# Federal Debt                                           -0.30
# quarterly_mean                                         -0.47
# half_year_mean                                         -0.53
# annual_mean                                            -0.56
# annual_quarterly_mean                                  -0.44
# annual_half_mean                                       -0.35
#
#                                       National Activity Index  \
# Yield of the ten-year Treasury Notes                     0.13
# Real Risk Premium                                        0.20
# Inflation Risk Premium                                   0.27
# National Activity Index                                  1.00
# Consumer Sentiment                                       0.20
# Labor Force Participation                                0.01
# Unemploymentrate                                        -0.08
# Borrowings from FED                                     -0.26
# Reserves Depository Institutions                        -0.03
# M2                                                      -0.06
# M3                                                      -0.38
# 1-Month Real Interest                                   -0.03
# 1-Year Real Interest                                     0.01
# 10-Year Real Interest                                    0.12
# 1-Year Expected Inflation                                0.16
# 2-Year Expected Inflation                                0.15
# 3-Year Expected Inflation                                0.14
# 4-Year Expected Inflation                                0.14
# 5-Year Expected Inflation                                0.14
# 10-Year Expected Inflation                               0.14
# Velocity of M2                                           0.05
# GDP                                                      0.64
# Real GDP                                                -0.10
# Federal Debt                                            -0.07
# quarterly_mean                                          -0.46
# half_year_mean                                          -0.38
# annual_mean                                             -0.27
# annual_quarterly_mean                                   -0.01
# annual_half_mean                                        -0.02
#
#                                       Consumer Sentiment  \
# Yield of the ten-year Treasury Notes                0.27
# Real Risk Premium                                   0.34
# Inflation Risk Premium                              0.26
# National Activity Index                             0.20
# Consumer Sentiment                                  1.00
# Labor Force Participation                           0.20
# Unemploymentrate                                   -0.61
# Borrowings from FED                                -0.50
# Reserves Depository Institutions                   -0.20
# M2                                                 -0.20
# M3                                                 -0.12
# 1-Month Real Interest                               0.35
# 1-Year Real Interest                                0.37
# 10-Year Real Interest                               0.33
# 1-Year Expected Inflation                           0.29
# 2-Year Expected Inflation                           0.31
# 3-Year Expected Inflation                           0.31
# 4-Year Expected Inflation                           0.31
# 5-Year Expected Inflation                           0.31
# 10-Year Expected Inflation                          0.30
# Velocity of M2                                      0.28
# GDP                                                 0.20
# Real GDP                                           -0.18
# Federal Debt                                       -0.21
# quarterly_mean                                     -0.13
# half_year_mean                                     -0.18
# annual_mean                                        -0.22
# annual_quarterly_mean                              -0.21
# annual_half_mean                                   -0.18
#
#                                       Labor Force Participation  \
# Yield of the ten-year Treasury Notes                       0.49
# Real Risk Premium                                          0.28
# Inflation Risk Premium                                     0.25
# National Activity Index                                    0.01
# Consumer Sentiment                                         0.20
# Labor Force Participation                                  1.00
# Unemploymentrate                                          -0.23
# Borrowings from FED                                       -0.03
# Reserves Depository Institutions                          -0.90
# M2                                                        -0.81
# M3                                                        -0.29
# 1-Month Real Interest                                      0.42
# 1-Year Real Interest                                       0.45
# 10-Year Real Interest                                      0.50
# 1-Year Expected Inflation                                  0.42
# 2-Year Expected Inflation                                  0.44
# 3-Year Expected Inflation                                  0.45
# 4-Year Expected Inflation                                  0.45
# 5-Year Expected Inflation                                  0.45
# 10-Year Expected Inflation                                 0.45
# Velocity of M2                                             0.94
# GDP                                                       -0.01
# Real GDP                                                  -0.59
# Federal Debt                                              -0.82
# quarterly_mean                                            -0.07
# half_year_mean                                            -0.11
# annual_mean                                               -0.17
# annual_quarterly_mean                                     -0.15
# annual_half_mean                                          -0.13
#
#                                       Unemploymentrate  Borrowings from FED  \
# Yield of the ten-year Treasury Notes              0.12                -0.20
# Real Risk Premium                                -0.06                -0.17
# Inflation Risk Premium                           -0.07                -0.25
# National Activity Index                          -0.08                -0.26
# Consumer Sentiment                               -0.61                -0.50
# Labor Force Participation                        -0.23                -0.03
# Unemploymentrate                                  1.00                 0.31
# Borrowings from FED                               0.31                 1.00
# Reserves Depository Institutions                  0.06                 0.09
# M2                                               -0.09                 0.16
# M3                                                0.25                 0.13
# 1-Month Real Interest                            -0.04                -0.01
# 1-Year Real Interest                             -0.02                -0.11
# 10-Year Real Interest                             0.07                -0.21
# 1-Year Expected Inflation                        -0.00                -0.32
# 2-Year Expected Inflation                         0.04                -0.28
# 3-Year Expected Inflation                         0.05                -0.26
# 4-Year Expected Inflation                         0.06                -0.25
# 5-Year Expected Inflation                         0.07                -0.25
# 10-Year Expected Inflation                        0.09                -0.24
# Velocity of M2                                   -0.21                -0.13
# GDP                                               0.03                -0.30
# Real GDP                                         -0.21                 0.18
# Federal Debt                                     -0.06                 0.14
# quarterly_mean                                    0.14                 0.08
# half_year_mean                                    0.21                 0.11
# annual_mean                                       0.29                 0.13
# annual_quarterly_mean                             0.28                 0.13
# annual_half_mean                                  0.24                 0.11
#
#                                       Reserves Depository Institutions    M2  \
# Yield of the ten-year Treasury Notes                             -0.71 -0.84
# Real Risk Premium                                                -0.33 -0.41
# Inflation Risk Premium                                           -0.22 -0.32
# National Activity Index                                          -0.03 -0.06
# Consumer Sentiment                                               -0.20 -0.20
# Labor Force Participation                                        -0.90 -0.81
# Unemploymentrate                                                  0.06 -0.09
# Borrowings from FED                                               0.09  0.16
# Reserves Depository Institutions                                  1.00  0.92
# M2                                                                0.92  1.00
# M3                                                                0.22  0.23
# 1-Month Real Interest                                            -0.58 -0.61
# 1-Year Real Interest                                             -0.66 -0.70
# 10-Year Real Interest                                            -0.71 -0.83
# 1-Year Expected Inflation                                        -0.62 -0.73
# 2-Year Expected Inflation                                        -0.66 -0.78
# 3-Year Expected Inflation                                        -0.66 -0.79
# 4-Year Expected Inflation                                        -0.67 -0.80
# 5-Year Expected Inflation                                        -0.67 -0.80
# 10-Year Expected Inflation                                       -0.67 -0.81
# Velocity of M2                                                   -0.87 -0.81
# GDP                                                              -0.06 -0.12
# Real GDP                                                          0.76  0.92
# Federal Debt                                                      0.93  0.99
# quarterly_mean                                                    0.05  0.06
# half_year_mean                                                    0.07  0.09
# annual_mean                                                       0.09  0.15
# annual_quarterly_mean                                             0.07  0.14
# annual_half_mean                                                  0.05  0.12
#
#                                       ...  10-Year Expected Inflation  \
# Yield of the ten-year Treasury Notes  ...                        0.99
# Real Risk Premium                     ...                        0.50
# Inflation Risk Premium                ...                        0.31
# National Activity Index               ...                        0.14
# Consumer Sentiment                    ...                        0.30
# Labor Force Participation             ...                        0.45
# Unemploymentrate                      ...                        0.09
# Borrowings from FED                   ...                       -0.24
# Reserves Depository Institutions      ...                       -0.67
# M2                                    ...                       -0.81
# M3                                    ...                       -0.14
# 1-Month Real Interest                 ...                        0.68
# 1-Year Real Interest                  ...                        0.84
# 10-Year Real Interest                 ...                        0.99
# 1-Year Expected Inflation             ...                        0.95
# 2-Year Expected Inflation             ...                        0.99
# 3-Year Expected Inflation             ...                        1.00
# 4-Year Expected Inflation             ...                        1.00
# 5-Year Expected Inflation             ...                        1.00
# 10-Year Expected Inflation            ...                        1.00
# Velocity of M2                        ...                        0.46
# GDP                                   ...                        0.31
# Real GDP                              ...                       -0.92
# Federal Debt                          ...                       -0.82
# quarterly_mean                        ...                       -0.11
# half_year_mean                        ...                       -0.15
# annual_mean                           ...                       -0.20
# annual_quarterly_mean                 ...                       -0.19
# annual_half_mean                      ...                       -0.17
#
#                                       Velocity of M2   GDP  Real GDP  \
# Yield of the ten-year Treasury Notes            0.49  0.29     -0.94
# Real Risk Premium                               0.32  0.23     -0.40
# Inflation Risk Premium                          0.30  0.26     -0.27
# National Activity Index                         0.05  0.64     -0.10
# Consumer Sentiment                              0.28  0.20     -0.18
# Labor Force Participation                       0.94 -0.01     -0.59
# Unemploymentrate                               -0.21  0.03     -0.21
# Borrowings from FED                            -0.13 -0.30      0.18
# Reserves Depository Institutions               -0.87 -0.06      0.76
# M2                                             -0.81 -0.12      0.92
# M3                                             -0.29 -0.31      0.12
# 1-Month Real Interest                           0.44  0.05     -0.64
# 1-Year Real Interest                            0.46  0.13     -0.78
# 10-Year Real Interest                           0.51  0.28     -0.93
# 1-Year Expected Inflation                       0.41  0.35     -0.85
# 2-Year Expected Inflation                       0.44  0.33     -0.90
# 3-Year Expected Inflation                       0.45  0.32     -0.91
# 4-Year Expected Inflation                       0.45  0.31     -0.91
# 5-Year Expected Inflation                       0.45  0.31     -0.92
# 10-Year Expected Inflation                      0.46  0.31     -0.92
# Velocity of M2                                  1.00  0.03     -0.57
# GDP                                             0.03  1.00     -0.23
# Real GDP                                       -0.57 -0.23      1.00
# Federal Debt                                   -0.81 -0.15      0.92
# quarterly_mean                                 -0.08 -0.47      0.05
# half_year_mean                                 -0.12 -0.41      0.06
# annual_mean                                    -0.19 -0.26      0.09
# annual_quarterly_mean                          -0.18  0.00      0.08
# annual_half_mean                               -0.17  0.03      0.07
#
#                                       Federal Debt  quarterly_mean  \
# Yield of the ten-year Treasury Notes         -0.85           -0.12
# Real Risk Premium                            -0.41           -0.42
# Inflation Risk Premium                       -0.30           -0.47
# National Activity Index                      -0.07           -0.46
# Consumer Sentiment                           -0.21           -0.13
# Labor Force Participation                    -0.82           -0.07
# Unemploymentrate                             -0.06            0.14
# Borrowings from FED                           0.14            0.08
# Reserves Depository Institutions              0.93            0.05
# M2                                            0.99            0.06
# M3                                            0.22            0.51
# 1-Month Real Interest                        -0.62            0.14
# 1-Year Real Interest                         -0.72            0.10
# 10-Year Real Interest                        -0.84           -0.10
# 1-Year Expected Inflation                    -0.75           -0.16
# 2-Year Expected Inflation                    -0.79           -0.13
# 3-Year Expected Inflation                    -0.81           -0.12
# 4-Year Expected Inflation                    -0.81           -0.12
# 5-Year Expected Inflation                    -0.81           -0.11
# 10-Year Expected Inflation                   -0.82           -0.11
# Velocity of M2                               -0.81           -0.08
# GDP                                          -0.15           -0.47
# Real GDP                                      0.92            0.05
# Federal Debt                                  1.00            0.08
# quarterly_mean                                0.08            1.00
# half_year_mean                                0.11            0.94
# annual_mean                                   0.16            0.73
# annual_quarterly_mean                         0.14            0.29
# annual_half_mean                              0.13            0.14
#
#                                       half_year_mean  annual_mean  \
# Yield of the ten-year Treasury Notes           -0.15        -0.21
# Real Risk Premium                              -0.50        -0.55
# Inflation Risk Premium                         -0.53        -0.56
# National Activity Index                        -0.38        -0.27
# Consumer Sentiment                             -0.18        -0.22
# Labor Force Participation                      -0.11        -0.17
# Unemploymentrate                                0.21         0.29
# Borrowings from FED                             0.11         0.13
# Reserves Depository Institutions                0.07         0.09
# M2                                              0.09         0.15
# M3                                              0.57         0.54
# 1-Month Real Interest                           0.16         0.12
# 1-Year Real Interest                            0.10         0.05
# 10-Year Real Interest                          -0.13        -0.19
# 1-Year Expected Inflation                      -0.21        -0.25
# 2-Year Expected Inflation                      -0.17        -0.22
# 3-Year Expected Inflation                      -0.16        -0.21
# 4-Year Expected Inflation                      -0.15        -0.21
# 5-Year Expected Inflation                      -0.15        -0.21
# 10-Year Expected Inflation                     -0.15        -0.20
# Velocity of M2                                 -0.12        -0.19
# GDP                                            -0.41        -0.26
# Real GDP                                        0.06         0.09
# Federal Debt                                    0.11         0.16
# quarterly_mean                                  0.94         0.73
# half_year_mean                                  1.00         0.86
# annual_mean                                     0.86         1.00
# annual_quarterly_mean                           0.52         0.86
# annual_half_mean                                0.31         0.74
#
#                                       annual_quarterly_mean  annual_half_mean
# Yield of the ten-year Treasury Notes                  -0.19             -0.18
# Real Risk Premium                                     -0.48             -0.40
# Inflation Risk Premium                                -0.44             -0.35
# National Activity Index                               -0.01             -0.02
# Consumer Sentiment                                    -0.21             -0.18
# Labor Force Participation                             -0.15             -0.13
# Unemploymentrate                                       0.28              0.24
# Borrowings from FED                                    0.13              0.11
# Reserves Depository Institutions                       0.07              0.05
# M2                                                     0.14              0.12
# M3                                                     0.32              0.22
# 1-Month Real Interest                                  0.07              0.02
# 1-Year Real Interest                                  -0.00             -0.03
# 10-Year Real Interest                                 -0.18             -0.17
# 1-Year Expected Inflation                             -0.22             -0.19
# 2-Year Expected Inflation                             -0.20             -0.18
# 3-Year Expected Inflation                             -0.20             -0.17
# 4-Year Expected Inflation                             -0.19             -0.17
# 5-Year Expected Inflation                             -0.19             -0.17
# 10-Year Expected Inflation                            -0.19             -0.17
# Velocity of M2                                        -0.18             -0.17
# GDP                                                    0.00              0.03
# Real GDP                                               0.08              0.07
# Federal Debt                                           0.14              0.13
# quarterly_mean                                         0.29              0.14
# half_year_mean                                         0.52              0.31
# annual_mean                                            0.86              0.74
# annual_quarterly_mean                                  1.00              0.94
# annual_half_mean                                       0.94              1.00
#
# [29 rows x 29 columns]

# %% [markdown]
# ### 4.2 Filter Method

# %%
# Visualize the correlations in a heatmap
plt.figure (figsize=(20,15))
sns.heatmap(corr, annot=True, cmap=plt.cm.Reds)
# plt.savefig('Correlation heatmap 1982.png', dpi= 1000)
plt.show()

# %%
# Visualize the correlations in a diagonal heatmap
f, ax = plt.subplots(figsize=(20, 17))
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
# Display the correlation to target variable
corr['Yield of the ten-year Treasury Notes'].sort_values(ascending=False)
# Out:
# Yield of the ten-year Treasury Notes    1.00
# 10-Year Expected Inflation              0.99
# 10-Year Real Interest                   0.99
# 5-Year Expected Inflation               0.99
# 4-Year Expected Inflation               0.99
# 3-Year Expected Inflation               0.99
# 2-Year Expected Inflation               0.98
# 1-Year Expected Inflation               0.94
# 1-Year Real Interest                    0.84
# 1-Month Real Interest                   0.69
# Real Risk Premium                       0.50
# Velocity of M2                          0.49
# Labor Force Participation               0.49
# Inflation Risk Premium                  0.31
# GDP                                     0.29
# Consumer Sentiment                      0.27
# National Activity Index                 0.13
# Unemploymentrate                        0.12
# quarterly_mean                         -0.12
# M3                                     -0.14
# half_year_mean                         -0.15
# annual_half_mean                       -0.18
# annual_quarterly_mean                  -0.19
# Borrowings from FED                    -0.20
# annual_mean                            -0.21
# Reserves Depository Institutions       -0.71
# M2                                     -0.84
# Federal Debt                           -0.85
# Real GDP                               -0.94
# Name: Yield of the ten-year Treasury Notes, dtype: float64

# %%
# Datasets with correlation higher than 0.5 to target variable
cor_target = abs(corr['Yield of the ten-year Treasury Notes'])
# Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Yield of the ten-year Treasury Notes   1.00
# Reserves Depository Institutions       0.71
# M2                                     0.84
# 1-Month Real Interest                  0.69
# 1-Year Real Interest                   0.84
# 10-Year Real Interest                  0.99
# 1-Year Expected Inflation              0.94
# 2-Year Expected Inflation              0.98
# 3-Year Expected Inflation              0.99
# 4-Year Expected Inflation              0.99
# 5-Year Expected Inflation              0.99
# 10-Year Expected Inflation             0.99
# Real GDP                               0.94
# Federal Debt                           0.85
# Name: Yield of the ten-year Treasury Notes, dtype: float64

# %% [markdown]
# ## <a id='regression_fm'></a>
# ## 5. Creating regression models with features from Filter Method

# %% [markdown]
# ### Definition of variables, train-test splitting

# %%
y = df_forecast['Yield of the ten-year Treasury Notes']
X = df_forecast[['Reserves Depository Institutions',
               'M2',
               '1-Month Real Interest',
               '1-Year Real Interest',
               '10-Year Real Interest',
               '1-Year Expected Inflation',
               '2-Year Expected Inflation', 
               '3-Year Expected Inflation', 
               '4-Year Expected Inflation',
               '5-Year Expected Inflation',
               '10-Year Expected Inflation',
               'Real GDP', 
               'Federal Debt']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# %%
print('Number of training data:', len(X_train))
print('Number of test data:', len(X_test))
# Out:
# Number of training data: 373
# Number of test data: 94

# %% [markdown]
# ### 5.1 Linear Regression

# %%
# Create Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print ("Training Set Score R^2: {:.2f}".format(lr.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -5.50

# %% [markdown]
# #### 5.1.1 Feature importance

# %%
cols = X_train.columns

# Derive feature importance from Linear Regression
importances = lr.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.2 Ridge

# %% [markdown]
# #### 5.2.1 Rigde alpha 0.1

# %%
# Create Ridge model
rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.01)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -4.39

# %% [markdown]
# #### 5.2.2 Rigde alpha 1

# %%
# Create Ridge model
rr1 = Ridge(alpha=1)
rr1.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr1.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr1.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -3.95

# %% [markdown]
# #### 5.2.3 Rigde alpha 10

# %%
# Create Ridge model
rr10 = Ridge(alpha=10)
rr10.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr10.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr10.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -3.60

# %% [markdown]
# #### 5.2.4 Feature importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Ridge with alpha 0.1
importances = rr.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Ridge with alpha 1
importances = rr1.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Ridge with alpha 10
importances = rr10.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.3 LASSO

# %%
# Create LASSO model
lasso = make_pipeline(StandardScaler(), LassoCV())
lasso.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('lassocv', LassoCV())])

# %%
print ("Training Set Score R^2: {:.2f}".format(lasso.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(lasso.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -2.25

# %% [markdown]
# #### 5.3.1 Feature importance

# %%
lasso_cv_coef = lasso[-1].coef_

# %%
# Derive feature importance from LASSO
importances = lasso_cv_coef
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.4 Elastic Net

# %%
# Create Elastic Net model
encv = make_pipeline(StandardScaler(), ElasticNetCV())
encv.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('elasticnetcv', ElasticNetCV())])

# %%
print ("Training Set Score R^2: {:.2f}".format(encv.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(encv.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -1.48

# %% [markdown]
# #### 5.4.1 Feature importance

# %%
encv_cv_coef = encv[-1].coef_

# %%
# Derive feature importance from Elastic Net
importances = encv_cv_coef
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.5 Decision Tree

# %% [markdown]
# #### 5.5.1 Decision Tree max_depth 3

# %%
# Create Decision Tree model
reg_tree = DecisionTreeRegressor(max_depth=3)

# Train Decision Tree Classifer
reg_tree = reg_tree.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.98
# Test Set Score R^2: -0.92

# %% [markdown]
# #### 5.5.2 Decision Tree max_depth 5

# %%
# Create Decision Tree model
reg_tree5 = DecisionTreeRegressor(max_depth=5)

# Train Decision Tree Classifer
reg_tree5 = reg_tree5.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree5.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree5.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.36

# %% [markdown]
# #### 5.5.3 Decision Tree max_depth 10

# %%
# Create Decision Tree model
reg_tree10 = DecisionTreeRegressor(max_depth=10)

# Train Decision Tree Classifer
reg_tree10 = reg_tree10.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree10.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree10.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.18

# %% [markdown]
# #### 5.5.4 Feature importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Decision Tree with max_depth 3
importances = reg_tree.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Decision Tree with max_depth 5
importances = reg_tree5.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Decision Tree with max_depth 10
importances = reg_tree10.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.6 Random Forest

# %% [markdown]
# #### 5.6.1 Random Forest with 100 trees

# %%
# Create Random Forest model
rf100 = RandomForestRegressor(n_estimators=100)
rf100.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print ("Training Set Score R^2: {:.2f}".format(rf100.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf100.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.20

# %% [markdown]
# #### 5.6.2 Random Forest with 500 trees

# %%
# Create Random Forest model
rf500 = RandomForestRegressor(n_estimators=500)
rf500.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
print ("Training Set Score R^2: {:.2f}".format(rf500.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf500.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.23

# %% [markdown]
# #### 5.6.3 Random Forest with 1000 trees

# %%
# Create Random Forest model
rf1000 = RandomForestRegressor(n_estimators=1000)
rf1000.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
print ("Training Set Score R^2: {:.2f}".format(rf1000.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf1000.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.20

# %% [markdown]
# #### 5.6.4 Feature importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Random Forest wit 100 trees
importances = rf100.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf100.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Random Forest wit 500 trees
importances = rf500.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf500.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Random Forest wit 1000 trees
importances = rf1000.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf1000.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 5.7 XGBoost

# %% [markdown]
# #### 5.7.1 XGBoost tree based

# %%
# Create XGBoost model
xgb_reg = xgb.XGBRegressor(booster='gbtree')
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
print ("Training Set Score R^2: {:.2f}".format(xgb_reg.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(xgb_reg.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.30

# %% [markdown]
# #### 5.7.2 XGBoost linear based

# %%
# Create XGBoost model
xgb_lin = xgb.XGBRegressor(booster='gblinear')
xgb_lin.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.5, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=0,
#              num_parallel_tree=None, predictor=None, random_state=0,
#              reg_alpha=0, reg_lambda=0, ...)

# %%
print ("Training Set Score R^2: {:.2f}".format(xgb_lin.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(xgb_lin.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.98
# Test Set Score R^2: 0.24

# %% [markdown]
# #### 5.7.3 Feature importance

# %%
# Tree based importance
xgb.plot_importance(xgb_reg)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Linear based importance
xgb.plot_importance(xgb_lin)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### 5.8 Pipeline

# %%
# Name of all the models
models = [
    ('Linear Regression', lr),
    ('Ridge, Alpha 0.1', rr),
    ('Ridge, Alpha 1', rr1),
    ('Ridge, Alpha 10', rr10),
    ('LassoCV', lasso),
    ('ElasticNetCV', encv),                            
    ('Decision Tree, maxDepth=3', reg_tree),
    ('Decision Tree, maxDepth=5', reg_tree5),
    ('Decision Tree, maxDepth=10', reg_tree10),
    ('Random Forest, trees=100', rf100),
    ('Random Forest, trees=500', rf500),
    ('Random Forest, trees=1000', rf1000),
    ('XGBOOst, Tree', xgb_reg),
    ('XGBOOst, Linear',xgb_lin)]

# %%
for name, model in models:
    pipelined_model = Pipeline([ 
                                 (name, model)
                            ])
    
    # Train the model
    pipelined_model.fit(X_train, y_train)

    # Predict the model
    y_hat = pipelined_model.predict(X_test)

    # Calculate metrics
    MAE = mean_absolute_error(y_test, y_hat)
    MSE = mean_squared_error(y_test, y_hat, squared=True)
    RMSE = mean_squared_error(y_test, y_hat, squared=False)
    MAPE = mean_absolute_percentage_error(y_test, y_hat)
    R2_train = pipelined_model.score(X_train, y_train)
    R2_test = r2_score(y_test, y_hat)
    print('Model: ', name, ' | R2 Train: ', R2_train)
    print('Model: ', name, ' | R2 Test: ', R2_test)
    print('Model: ', name, ' | MAE: ', MAE)
    print('Model: ', name, ' | MSE: ', MSE)
    print('Model: ', name, ' | RMSE: ', RMSE)
    print('Model: ', name, ' | MAPE: ', MAPE)
    print('----------------')
# Out:
# Model:  Linear Regression  | R2 Train:  0.9930614017611834
# Model:  Linear Regression  | R2 Test:  -5.496123643979374
# Model:  Linear Regression  | MAE:  1.528267919825075
# Model:  Linear Regression  | MSE:  2.6838342244559152
# Model:  Linear Regression  | RMSE:  1.6382411984979242
# Model:  Linear Regression  | MAPE:  0.9778144173957022
# ----------------
# Model:  Ridge, Alpha 0.1  | R2 Train:  0.992480798776624
# Model:  Ridge, Alpha 0.1  | R2 Test:  -4.385591553513531
# Model:  Ridge, Alpha 0.1  | MAE:  1.3378968666762092
# Model:  Ridge, Alpha 0.1  | MSE:  2.225024602734641
# Model:  Ridge, Alpha 0.1  | RMSE:  1.4916516358502212
# Model:  Ridge, Alpha 0.1  | MAPE:  0.9037596149102147
# ----------------
# Model:  Ridge, Alpha 1  | R2 Train:  0.9923734776700099
# Model:  Ridge, Alpha 1  | R2 Test:  -3.9455544733352577
# Model:  Ridge, Alpha 1  | MAE:  1.2863830438185604
# Model:  Ridge, Alpha 1  | MSE:  2.0432259424048542
# Model:  Ridge, Alpha 1  | RMSE:  1.4294145453313585
# Model:  Ridge, Alpha 1  | MAPE:  0.8679257758938556
# ----------------
# Model:  Ridge, Alpha 10  | R2 Train:  0.9917748144370983
# Model:  Ridge, Alpha 10  | R2 Test:  -3.5984889844160115
# Model:  Ridge, Alpha 10  | MAE:  1.2325200447999647
# Model:  Ridge, Alpha 10  | MSE:  1.899837933133774
# Model:  Ridge, Alpha 10  | RMSE:  1.378346086124154
# Model:  Ridge, Alpha 10  | MAPE:  0.8410638163869066
# ----------------
# Model:  LassoCV  | R2 Train:  0.9921270117594789
# Model:  LassoCV  | R2 Test:  -2.2532311989118403
# Model:  LassoCV  | MAE:  1.074271118255131
# Model:  LassoCV  | MSE:  1.34405280906243
# Model:  LassoCV  | RMSE:  1.15933291554343
# Model:  LassoCV  | MAPE:  0.7043304457539753
# ----------------
# Model:  ElasticNetCV  | R2 Train:  0.9917564187971546
# Model:  ElasticNetCV  | R2 Test:  -1.4822103748134139
# Model:  ElasticNetCV  | MAE:  0.9473696200684151
# Model:  ElasticNetCV  | MSE:  1.0255102152185787
# Model:  ElasticNetCV  | RMSE:  1.0126747825529077
# Model:  ElasticNetCV  | MAPE:  0.6161977012581391
# ----------------
# Model:  Decision Tree, maxDepth=3  | R2 Train:  0.9756642530082973
# Model:  Decision Tree, maxDepth=3  | R2 Test:  -0.9235524676529601
# Model:  Decision Tree, maxDepth=3  | MAE:  0.7319463544369489
# Model:  Decision Tree, maxDepth=3  | MSE:  0.7947040771011586
# Model:  Decision Tree, maxDepth=3  | RMSE:  0.8914617642395879
# Model:  Decision Tree, maxDepth=3  | MAPE:  0.5009113889664836
# ----------------
# Model:  Decision Tree, maxDepth=5  | R2 Train:  0.9959147310794633
# Model:  Decision Tree, maxDepth=5  | R2 Test:  -0.17928992886890804
# Model:  Decision Tree, maxDepth=5  | MAE:  0.6314906281661599
# Model:  Decision Tree, maxDepth=5  | MSE:  0.4872165071223522
# Model:  Decision Tree, maxDepth=5  | RMSE:  0.6980089591992013
# Model:  Decision Tree, maxDepth=5  | MAPE:  0.40600865207964965
# ----------------
# Model:  Decision Tree, maxDepth=10  | R2 Train:  0.9999091076777868
# Model:  Decision Tree, maxDepth=10  | R2 Test:  -0.1697216507694752
# Model:  Decision Tree, maxDepth=10  | MAE:  0.619095744680851
# Model:  Decision Tree, maxDepth=10  | MSE:  0.4832634308510639
# Model:  Decision Tree, maxDepth=10  | RMSE:  0.6951715118235671
# Model:  Decision Tree, maxDepth=10  | MAPE:  0.4238534055707988
# ----------------
# Model:  Random Forest, trees=100  | R2 Train:  0.999010574112536
# Model:  Random Forest, trees=100  | R2 Test:  -0.23514814230223768
# Model:  Random Forest, trees=100  | MAE:  0.6708617021276603
# Model:  Random Forest, trees=100  | MSE:  0.5102939904255331
# Model:  Random Forest, trees=100  | RMSE:  0.7143486476683029
# Model:  Random Forest, trees=100  | MAPE:  0.43052755589059905
# ----------------
# Model:  Random Forest, trees=500  | R2 Train:  0.9990881085241686
# Model:  Random Forest, trees=500  | R2 Test:  -0.21451236742069812
# Model:  Random Forest, trees=500  | MAE:  0.6678002127659539
# Model:  Random Forest, trees=500  | MSE:  0.5017684447446759
# Model:  Random Forest, trees=500  | RMSE:  0.7083561567069745
# Model:  Random Forest, trees=500  | MAPE:  0.4267257166153426
# ----------------
# Model:  Random Forest, trees=1000  | R2 Train:  0.9990934541741721
# Model:  Random Forest, trees=1000  | R2 Test:  -0.22615801376309164
# Model:  Random Forest, trees=1000  | MAE:  0.6714270212765888
# Model:  Random Forest, trees=1000  | MSE:  0.5065797731510544
# Model:  Random Forest, trees=1000  | RMSE:  0.7117441767594972
# Model:  Random Forest, trees=1000  | MAPE:  0.42874582629383506
# ----------------
# Model:  XGBOOst, Tree  | R2 Train:  0.9999986550737996
# Model:  XGBOOst, Tree  | R2 Test:  -0.301941081553752
# Model:  XGBOOst, Tree  | MAE:  0.6867304409818445
# Model:  XGBOOst, Tree  | MSE:  0.5378890896169346
# Model:  XGBOOst, Tree  | RMSE:  0.7334092238422794
# Model:  XGBOOst, Tree  | MAPE:  0.4380637989037507
# ----------------
# Model:  XGBOOst, Linear  | R2 Train:  0.9752730720059141
# Model:  XGBOOst, Linear  | R2 Test:  -2.3637247640863044
# Model:  XGBOOst, Linear  | MAE:  0.937125933855138
# Model:  XGBOOst, Linear  | MSE:  1.3897025577509754
# Model:  XGBOOst, Linear  | RMSE:  1.1788564618947361
# Model:  XGBOOst, Linear  | MAPE:  0.6287366516902029
# ----------------

# %% [markdown]
# ## <a id='regression_all'></a>
# ## 6. Creating Regression models with all the features

# %% [markdown]
# ### Definition of variables, train-test splitting

# %%
y = df_forecast['Yield of the ten-year Treasury Notes']
X = df_forecast.drop('Yield of the ten-year Treasury Notes',1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# %%
print('Number of training data:', len(X_train))
print('Number of test data:', len(X_test))
# Out:
# Number of training data: 373
# Number of test data: 94

# %% [markdown]
# ### 6.1 Linear Regression

# %%
# Create Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print ("Training Set Score R^2: {:.2f}".format(lr.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: -0.66

# %% [markdown]
# #### 6.1.1 Feature importance

# %%
cols = X_train.columns

# Derive feature importance from Linear Regression
importances = lr.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.2 Ridge

# %% [markdown]
# #### 6.2.1 Rigde alpha 0.1

# %%
# Create Ridge model
rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.01)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: 0.37

# %% [markdown]
# #### 6.2.2 Rigde alpha 1

# %%
# Create Ridge model
rr1 = Ridge(alpha=1)
rr1.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr1.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr1.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: 0.63

# %% [markdown]
# #### 6.2.3 Rigde alpha 10

# %%
# Create Ridge model
rr10 = Ridge(alpha=10)
rr10.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
print ("Training Set Score R^2: {:.2f}".format(rr10.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rr10.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: 0.65

# %% [markdown]
# #### 6.2.4 Feature importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Ridge with alpha 0.1
importances = rr.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Ridge with alpha 1
importances = rr1.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Ridge with alpha 10
importances = rr10.coef_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.3 LASSO

# %%
# Create LASSO model
lasso = make_pipeline(StandardScaler(), LassoCV())
lasso.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('lassocv', LassoCV())])

# %%
print ("Training Set Score R^2: {:.2f}".format(lasso.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(lasso.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: 0.30

# %% [markdown]
# #### 6.3.1 Feature importance

# %%
lasso_cv_coef = lasso[-1].coef_

# %%
# Derive feature importance from LASSO
importances = lasso_cv_coef
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.4 Elastic Net

# %%
# Create Elastic Net model
encv = make_pipeline(StandardScaler(), ElasticNetCV())
encv.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('elasticnetcv', ElasticNetCV())])

# %%
print ("Training Set Score R^2: {:.2f}".format(encv.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(encv.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.99
# Test Set Score R^2: 0.64

# %% [markdown]
# #### 6.4.1 Feature importance

# %%
encv_cv_coef = encv[-1].coef_

# %%
# Derive feature importance from Elastic Net
importances = encv_cv_coef
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.5 Decision Tree

# %% [markdown]
# #### 6.5.1 Decision Tree max_depth 3

# %%
# Create Decision Tree model
reg_tree = DecisionTreeRegressor(max_depth=3)

# Train Decision Tree Classifer
reg_tree = reg_tree.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.98
# Test Set Score R^2: -0.92

# %% [markdown]
# #### 6.5.2 Decision Tree max_depth 5

# %%
# Create Decision Tree model
reg_tree5 = DecisionTreeRegressor(max_depth=5)

# Train Decision Tree Classifer
reg_tree5 = reg_tree5.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree5.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree5.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.15

# %% [markdown]
# #### 6.5.3 Decision Tree max_depth 10

# %%
# Create Decision Tree model
reg_tree10 = DecisionTreeRegressor(max_depth=10)

# Train Decision Tree Classifer
reg_tree10 = reg_tree10.fit(X_train, y_train)

# %%
print ("Training Set Score R^2: {:.2f}".format(reg_tree10.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(reg_tree10.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.14

# %% [markdown]
# #### 6.5.4 Feature importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Decision Tree with max_depth 3
importances = reg_tree.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Decision Tree with max_depth 5
importances = reg_tree5.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Decision Tree with max_depth 10
importances = reg_tree10.feature_importances_
indices     = np.argsort(importances)[::-1]

# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.6 Random Forest

# %%
# Create Random Forest model
rf100 = RandomForestRegressor(n_estimators=100)
rf100.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
print ("Training Set Score R^2: {:.2f}".format(rf100.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf100.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.37

# %% [markdown]
# #### 6.6.2 Random Forest with 500 trees

# %%
# Create Random Forest model
rf500 = RandomForestRegressor(n_estimators=500)
rf500.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
print ("Training Set Score R^2: {:.2f}".format(rf500.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf500.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.33

# %% [markdown]
# #### 6.6.3 Random Forest with 1000 trees

# %%
# Create Random Forest model
rf1000 = RandomForestRegressor(n_estimators=1000)
rf1000.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
print ("Training Set Score R^2: {:.2f}".format(rf1000.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(rf1000.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.34

# %% [markdown]
# #### 6.6.4 Feature Importance

# %%
cols = X_train.columns

# %%
# Derive feature importance from Random Forest wit 100 trees
importances = rf100.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf100.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Random Forest wit 500 trees
importances = rf500.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf500.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %%
# Derive feature importance from Random Forest wit 1000 trees
importances = rf1000.feature_importances_
std         = np.std([tree.feature_importances_ for tree in rf1000.estimators_], axis=0)
indices     = np.argsort(importances)[::-1]


# Barplot with feature importance
df = pd.DataFrame({'features':cols,'importances': importances})
df.sort_values('importances', inplace=True)
df.plot(kind='barh', y='importances', x='features', color='r', figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='features'>

# %% [markdown]
# ### 6.7 XGBoost

# %% [markdown]
# #### 6.7.1 XGBoost tree based

# %%
# Create XGBoost model
xgb_reg = xgb.XGBRegressor(booster='gbtree')
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
print ("Training Set Score R^2: {:.2f}".format(xgb_reg.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(xgb_reg.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 1.00
# Test Set Score R^2: -0.39

# %% [markdown]
# #### 6.7.2 XGBoost linear based

# %%
# Create XGBoost model
xgb_lin = xgb.XGBRegressor(booster='gblinear')
xgb_lin.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gblinear', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None, gpu_id=-1,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.5, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=0,
#              num_parallel_tree=None, predictor=None, random_state=0,
#              reg_alpha=0, reg_lambda=0, ...)

# %%
print ("Training Set Score R^2: {:.2f}".format(xgb_lin.score(X_train, y_train)))
print ("Test Set Score R^2: {:.2f}".format(xgb_lin.score(X_test, y_test)))
# Out:
# Training Set Score R^2: 0.97
# Test Set Score R^2: -1.36

# %% [markdown]
# #### 6.7.3 Feature importance

# %%
# Tree based importance
xgb.plot_importance(xgb_reg)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
# Linear based importance
xgb.plot_importance(xgb_lin)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### 6.8 Pipeline

# %%
# Name of all the models
models = [
    ('Linear Regression', lr),
    ('Ridge, Alpha 0.1', rr),
    ('Ridge, Alpha 1', rr1),
    ('Ridge, Alpha 10', rr10),
    ('LassoCV', lasso),
    ('ElasticNetCV', encv),                            
    ('Decision Tree, maxDepth=3', reg_tree),
    ('Decision Tree, maxDepth=5', reg_tree5),
    ('Decision Tree, maxDepth=10', reg_tree10),
    ('Random Forest, trees=100', rf100),
    ('Random Forest, trees=500', rf500),
    ('Random Forest, trees=1000', rf1000),
    ('XGBOOst, Tree', xgb_reg),
    ('XGBOOst, Linear',xgb_lin)]

# %%
for name, model in models:
    pipelined_model = Pipeline([ 
                                 (name, model)
                            ])
    
    # Train the model
    pipelined_model.fit(X_train, y_train)

    # Predict the model
    y_hat = pipelined_model.predict(X_test)

    # Calculate metrics
    MAE = mean_absolute_error(y_test, y_hat)
    MSE = mean_squared_error(y_test, y_hat, squared=True)
    RMSE = mean_squared_error(y_test, y_hat, squared=False)
    MAPE = mean_absolute_percentage_error(y_test, y_hat)
    R2_train = pipelined_model.score(X_train, y_train)
    R2_test = r2_score(y_test, y_hat)
    print('Model: ', name, ' | R2 Train: ', R2_train)
    print('Model: ', name, ' | R2 Test: ', R2_test)
    print('Model: ', name, ' | MAE: ', MAE)
    print('Model: ', name, ' | MSE: ', MSE)
    print('Model: ', name, ' | RMSE: ', RMSE)
    print('Model: ', name, ' | MAPE: ', MAPE)
    print('----------------')
# Out:
# Model:  Linear Regression  | R2 Train:  0.9949464153230825
# Model:  Linear Regression  | R2 Test:  -0.6627343903218093
# Model:  Linear Regression  | MAE:  0.723186108995998
# Model:  Linear Regression  | MSE:  0.6869486646950406
# Model:  Linear Regression  | RMSE:  0.8288236632089123
# Model:  Linear Regression  | MAPE:  0.4467522722786214
# ----------------
# Model:  Ridge, Alpha 0.1  | R2 Train:  0.9946409554020519
# Model:  Ridge, Alpha 0.1  | R2 Test:  0.37360220525520504
# Model:  Ridge, Alpha 0.1  | MAE:  0.4535028084334064
# Model:  Ridge, Alpha 0.1  | MSE:  0.2587924632896858
# Model:  Ridge, Alpha 0.1  | RMSE:  0.5087164861587304
# Model:  Ridge, Alpha 0.1  | MAPE:  0.2780940552250262
# ----------------
# Model:  Ridge, Alpha 1  | R2 Train:  0.9939243638275836
# Model:  Ridge, Alpha 1  | R2 Test:  0.6272372194806657
# Model:  Ridge, Alpha 1  | MAE:  0.34755853014305726
# Model:  Ridge, Alpha 1  | MSE:  0.15400468999513928
# Model:  Ridge, Alpha 1  | RMSE:  0.39243431296860276
# Model:  Ridge, Alpha 1  | MAPE:  0.22829941757191977
# ----------------
# Model:  Ridge, Alpha 10  | R2 Train:  0.9931457317984869
# Model:  Ridge, Alpha 10  | R2 Test:  0.6549135746176202
# Model:  Ridge, Alpha 10  | MAE:  0.3058904276916454
# Model:  Ridge, Alpha 10  | MSE:  0.1425703711312124
# Model:  Ridge, Alpha 10  | RMSE:  0.37758491909928343
# Model:  Ridge, Alpha 10  | MAPE:  0.22157127886889003
# ----------------
# Model:  LassoCV  | R2 Train:  0.9944023722252165
# Model:  LassoCV  | R2 Test:  0.2960892592277363
# Model:  LassoCV  | MAE:  0.48352521418733907
# Model:  LassoCV  | MSE:  0.2908164684946559
# Model:  LassoCV  | RMSE:  0.5392740198587875
# Model:  LassoCV  | MAPE:  0.30249462955852924
# ----------------
# Model:  ElasticNetCV  | R2 Train:  0.9941998063476828
# Model:  ElasticNetCV  | R2 Test:  0.637945828260297
# Model:  ElasticNetCV  | MAE:  0.3324633753006063
# Model:  ElasticNetCV  | MSE:  0.1495804929948682
# Model:  ElasticNetCV  | RMSE:  0.38675637421362324
# Model:  ElasticNetCV  | MAPE:  0.2147942508335818
# ----------------
# Model:  Decision Tree, maxDepth=3  | R2 Train:  0.9756642530082973
# Model:  Decision Tree, maxDepth=3  | R2 Test:  -0.9235524676529607
# Model:  Decision Tree, maxDepth=3  | MAE:  0.7319463544369489
# Model:  Decision Tree, maxDepth=3  | MSE:  0.794704077101159
# Model:  Decision Tree, maxDepth=3  | RMSE:  0.8914617642395881
# Model:  Decision Tree, maxDepth=3  | MAPE:  0.5009113889664836
# ----------------
# Model:  Decision Tree, maxDepth=5  | R2 Train:  0.9961976138763226
# Model:  Decision Tree, maxDepth=5  | R2 Test:  -0.15307094181804404
# Model:  Decision Tree, maxDepth=5  | MAE:  0.6254804964539005
# Model:  Decision Tree, maxDepth=5  | MSE:  0.47638429107564995
# Model:  Decision Tree, maxDepth=5  | RMSE:  0.6902059772818908
# Model:  Decision Tree, maxDepth=5  | MAPE:  0.40212841098257424
# ----------------
# Model:  Decision Tree, maxDepth=10  | R2 Train:  0.999968223746551
# Model:  Decision Tree, maxDepth=10  | R2 Test:  -0.43339185447754125
# Model:  Decision Tree, maxDepth=10  | MAE:  0.7069645390070921
# Model:  Decision Tree, maxDepth=10  | MSE:  0.5921971820330969
# Model:  Decision Tree, maxDepth=10  | RMSE:  0.7695434893708717
# Model:  Decision Tree, maxDepth=10  | MAPE:  0.45723026429975255
# ----------------
# Model:  Random Forest, trees=100  | R2 Train:  0.999171927294212
# Model:  Random Forest, trees=100  | R2 Test:  -0.3153476319558217
# Model:  Random Forest, trees=100  | MAE:  0.6949574468085113
# Model:  Random Forest, trees=100  | MSE:  0.5434279248936177
# Model:  Random Forest, trees=100  | RMSE:  0.737175640464074
# Model:  Random Forest, trees=100  | MAPE:  0.4390654117270963
# ----------------
# Model:  Random Forest, trees=500  | R2 Train:  0.9991437127585523
# Model:  Random Forest, trees=500  | R2 Test:  -0.3108686598026513
# Model:  Random Forest, trees=500  | MAE:  0.6958725531914871
# Model:  Random Forest, trees=500  | MSE:  0.5415774646170181
# Model:  Random Forest, trees=500  | RMSE:  0.7359194688395042
# Model:  Random Forest, trees=500  | MAPE:  0.4374252568830693
# ----------------
# Model:  Random Forest, trees=1000  | R2 Train:  0.9991760880859635
# Model:  Random Forest, trees=1000  | R2 Test:  -0.3313366918523184
# Model:  Random Forest, trees=1000  | MAE:  0.7009315957446772
# Model:  Random Forest, trees=1000  | MSE:  0.550033708360634
# Model:  Random Forest, trees=1000  | RMSE:  0.7416425745334703
# Model:  Random Forest, trees=1000  | MAPE:  0.44064980567625056
# ----------------
# Model:  XGBOOst, Tree  | R2 Train:  0.9999999003241258
# Model:  XGBOOst, Tree  | R2 Test:  -0.3937250715399212
# Model:  XGBOOst, Tree  | MAE:  0.7213800906627738
# Model:  XGBOOst, Tree  | MSE:  0.5758090903869788
# Model:  XGBOOst, Tree  | RMSE:  0.758820855266234
# Model:  XGBOOst, Tree  | MAPE:  0.44720553933115503
# ----------------
# Model:  XGBOOst, Linear  | R2 Train:  0.99156427278585
# Model:  XGBOOst, Linear  | R2 Test:  0.3421225114973625
# Model:  XGBOOst, Linear  | MAE:  0.3778482652725058
# Model:  XGBOOst, Linear  | MSE:  0.2717981085195132
# Model:  XGBOOst, Linear  | RMSE:  0.5213426018651394
# Model:  XGBOOst, Linear  | MAPE:  0.2729642117212184
# ----------------
